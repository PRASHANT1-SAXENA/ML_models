# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Boston=pd.read_csv(r"C:\Users\chemi\Desktop\enviroments\myml\1-machine learning tuto\Boston1.csv")

# %%
# Here medv is dependent varible and target varible which i have to predict and other are independent variable
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
Boston.shape
# Out:
# (506, 14)

# %%
# Here we can see no of entries, not null values and also data types of each column or attribute.
Boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univariate analysis

# %%
"""we can see the every statical part of each attribute
for instance we get insight from crim here is mean of this is 3.6 with the deviation of 8.6 
and it min is 0.6 and max is 88.97 most importantly insight is it 25% values are below .082 and 
50% value is below 0.256 and similary so on.
"""
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
""" Here we plot a line plot for each of the attribute"""
for i in Boston.columns:
    plt.figure()
    plt.plot(Boston[i])
    plt.ylabel(i)

# %%
for i in Boston.columns:
    plt.figure()
    # IF WANT SET BINS YOU CAN GIVE YOUR BINS
    plt.hist(Boston[i])

# %%
# Here is the boxplot from which you can understand how much datapoints covered what amount of data
# Also see which have the outliers
fig,axis=plt.subplots(nrows=4,ncols=4,figsize=(20,20))
 b                vvc                      
for i in Boston.columns:
    sns.boxplot(Boston[i],ax=axis[x,y])
    if y<3:
        y=y+1
    else:
        x=x+1
        y=0

# %% [markdown]
# ### Bivariate Analysis

# %%
""" Here we plot a line plot for each of the attribute w.r.t to medv(target varible) so you can 
the pattern"""
for i in Boston.columns:
    plt.figure()
    plt.plot(Boston[i])
    plt.plot(Boston["medv"])
    plt.xlabel("medv")
    plt.ylabel(i)

# %%
# Here we can see the correlation between the columns importantly with target varible 
print("Highest positive correlation between -- Nox and Indus")
print("Highest negative correlation between -- Nox and Dis")
print("Highest correlation with target variable is lstat")
plt.figure(figsize=(12,8))
sns.heatmap(Boston.corr(),annot= True)
plt.show()
# Out:
# Highest positive correlation between -- Nox and Indus
# Highest negative correlation between -- Nox and Dis
# Highest correlation with target variable is lstat

# %%
# Here is box plot with respect to each other 
plt.figure(figsize=(18,8))
Boston.plot(kind="box")
plt.xticks(rotation=90)
plt.show()

# %%
for i in Boston.columns:
    if i != "medv":
        plt.figure()
        sns.scatterplot(x=Boston[i],y=Boston["medv"],label=i)
        plt.xlabel(i)
        plt.legend()

# %% [markdown]
# ### Multivariate Analysis
# #####           when there is need of a relation between more than attributes then we have to  do multivariate analysis

# %% [markdown]
# # MODEL BUILDING

# %%
""" Here we know with target variable lstat has highest correlation so I first go with lstat and 
 add other further appropiate attribute in order to improve accurary  """
data=Boston.loc[:,["lstat","medv"]]
data
# Out:
#      lstat  medv
# 0     4.98  24.0
# 1     9.14  21.6
# 2     4.03  34.7
# 3     2.94  33.4
# 4     5.33  36.2
# ..     ...   ...
# 501   9.67  22.4
# 502   9.08  20.6
# 503   5.64  23.9
# 504   6.48  22.0
# 505   7.88  11.9
#
# [506 rows x 2 columns]

# %%
x=pd.DataFrame(data["lstat"])
y=pd.DataFrame(data["medv"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print("shape of x_train" , x_train.shape)
print("shape of y_train", y_train.shape)
print("shape of x_test" , x_test.shape)
print("shape of y_test" , y_test.shape)
# Out:
# shape of x_train (404, 1)
# shape of y_train (404, 1)
# shape of x_test (102, 1)
# shape of y_test (102, 1)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# To get value of c of best fit line i.e y=mx+c
print(model.intercept_)
# Out:
# [34.33497839]

# %%
# To get valuse of slope or coefficient of line 
print(model.coef_)
# Here it is negative as here is negative corelation between them so there is inverse relation btw them
# Out:
# [[-0.92441715]]

# %%
y_predict_train=model.predict(x_train)
y_predict_test=model.predict(x_test)

# %%
# r2 score is good as much as it is near to 1
from sklearn import metrics
from sklearn.metrics import r2_score
print('mean Absolute error_of_train: ', metrics.mean_absolute_error(y_train,y_predict_train))
print('mean Absolute error_of_test: ', metrics.mean_absolute_error(y_test,y_predict_test))
print('mean squared error_of_train: ', metrics.mean_squared_error(y_train,y_predict_train))
print('mean squared error_of_test: ' , metrics.mean_squared_error(y_test,y_predict_test))
print('root mean Absolute error_of_train: ', np.sqrt(metrics.mean_squared_error(y_train,y_predict_train)))
print('root mean Absolute error_of_test: ', np.sqrt(metrics.mean_squared_error(y_test,y_predict_test)))
print("r2_on_train: ", r2_score(y_train,y_predict_train))
print("r2_on_test:  ", r2_score(y_test,y_predict_test))
# Out:
# mean Absolute error_of_train:  4.38437515332486
# mean Absolute error_of_test:  5.078127727696937
# mean squared error_of_train:  36.389745631141025
# mean squared error_of_test:  46.994820919547124
# root mean Absolute error_of_train:  6.032391369195223
# root mean Absolute error_of_test:  6.855276866731724
# r2_on_train:  0.5495280791456811
# r2_on_test:   0.5244757432765152

# %%
# similary with do for other here try with rm
data_1=Boston.loc[:,["rm","medv"]]
data_1
# Out:
#         rm  medv
# 0    6.575  24.0
# 1    6.421  21.6
# 2    7.185  34.7
# 3    6.998  33.4
# 4    7.147  36.2
# ..     ...   ...
# 501  6.593  22.4
# 502  6.120  20.6
# 503  6.976  23.9
# 504  6.794  22.0
# 505  6.030  11.9
#
# [506 rows x 2 columns]

# %%
x_1=pd.DataFrame(data_1["rm"])
y_1=pd.DataFrame(data_1["medv"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train_1,x_test_1,y_train_1,y_test_1=train_test_split(x_1,y_1,test_size=0.2,random_state=1)
print("shape of x_train" , x_train_1.shape)
print("shape of y_train", y_train_1.shape)
print("shape of x_test" , x_test_1.shape)
print("shape of y_test" , y_test_1.shape)
# Out:
# shape of x_train (404, 1)
# shape of y_train (404, 1)
# shape of x_test (102, 1)
# shape of y_test (102, 1)

# %%
model=LinearRegression()
model.fit(x_train_1,y_train_1)
# Out:
# LinearRegression()

# %%
y_predict_test_1=model.predict(x_test_1)

# %%
print('mean Absolute error_of_test: ', metrics.mean_absolute_error(y_test_1,y_predict_test_1))
print('mean squared error_of_test: ' , metrics.mean_squared_error(y_test_1,y_predict_test_1))
print('root mean Absolute error_of_train: ', np.sqrt(metrics.mean_squared_error(y_test_1,y_predict_test_1)))
print("r2_on_test:  ", r2_score(y_test_1,y_predict_test_1))
# Out:
# mean Absolute error_of_test:  4.827325011761484
# mean squared error_of_test:  40.74441386633471
# root mean Absolute error_of_train:  6.383135112649168
# r2_on_test:   0.5877214395051774

# %% [markdown]
#  ##### so we can see model accuracy improve

# %% [markdown]
# ### NOW go with multiple columns

# %%
data_2=Boston.loc[:,["rm","lstat", "medv"]]
data_2
# Out:
#         rm  lstat  medv
# 0    6.575   4.98  24.0
# 1    6.421   9.14  21.6
# 2    7.185   4.03  34.7
# 3    6.998   2.94  33.4
# 4    7.147   5.33  36.2
# ..     ...    ...   ...
# 501  6.593   9.67  22.4
# 502  6.120   9.08  20.6
# 503  6.976   5.64  23.9
# 504  6.794   6.48  22.0
# 505  6.030   7.88  11.9
#
# [506 rows x 3 columns]

# %%
x_2=pd.DataFrame(data_2[["rm","lstat"]])
y_2=pd.DataFrame(data_2["medv"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train_2,x_test_2,y_train_2,y_test_2=train_test_split(x_2,y_2,test_size=0.2,random_state=1)
print("shape of x_train" , x_train_2.shape)
print("shape of y_train", y_train_2.shape)
print("shape of x_test" , x_test_2.shape)
print("shape of y_test" , y_test_2.shape)
# Out:
# shape of x_train (404, 2)
# shape of y_train (404, 1)
# shape of x_test (102, 2)
# shape of y_test (102, 1)

# %%
model=LinearRegression()
model.fit(x_train_2,y_train_2)
# Out:
# LinearRegression()

# %%
y_predict_test_2=model.predict(x_test_2)

# %%
print('mean Absolute error_of_test: ', metrics.mean_absolute_error(y_test_2,y_predict_test_2))
print('mean squared error_of_test: ' , metrics.mean_squared_error(y_test_2,y_predict_test_2))
print('root mean Absolute error_of_train: ', np.sqrt(metrics.mean_squared_error(y_test_2,y_predict_test_2)))
print("r2_on_test:  ", r2_score(y_test_2,y_predict_test_2))
# Out:
# mean Absolute error_of_test:  4.505211813354641
# mean squared error_of_test:  32.08375607139393
# root mean Absolute error_of_train:  5.664252472426871
# r2_on_test:   0.6753556251471675

# %% [markdown]
# ## AGAIN ACCURAY IMPROVE
# #### In this way we make linear regression model

# %%
"""Similary we go with all the variable at once and check the accuracy and try to find the best model
on test data"""
# Out:
# 'Similary we go with all the variable at once and check the accuracy and try to find the best model\non test data'
